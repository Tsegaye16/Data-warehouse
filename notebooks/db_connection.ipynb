# %% [markdown]
# ## Storing clean data to PostgreSQl

# %%
import pandas as pd
import os, sys

# %%
sys.path.append(os.path.abspath(os.path.join('..', 'scripts')))
from db_connection import TelegramDBManager

# %%
data = pd.read_csv("../data/cleaned_data.csv")

# %%
data.head()
# Out:
#    message_id channel_title         sender               message_date  \
# 0          97        CheMed -1001627056354  2023-02-10 12:23:06+00:00
# 1          96        CheMed -1001627056354  2023-02-02 08:58:52+00:00
# 2          95        CheMed -1001627056354  2023-02-01 08:59:37+00:00
# 3          94        CheMed -1001627056354  2023-01-31 09:19:53+00:00
# 4          93        CheMed -1001627056354  2023-01-30 09:45:25+00:00
#
#                                              message  \
# 0  ️Notice! Dear esteemed customers, Due to four-...
# 1  Mela-One በውስጡ ሆርሞን ያለው ድንገተኛ ወሊድ መቆጣጠርያ ሲሆን ያለ...
# 2  አዚትሮማይሲን በሃኪም መድሃኒት ማዘዣ ከሚታዘዙ አንቲባዮቲኮች አንዱ ሲሆን...
# 3  Che-Med Trivia #3  ምግብና መጠጦች አንዳንድ መድሃኒቶች በደንብ...
# 4  Che-Med Trivia #2  እንደ Ciprofloxacin, Doxycycl...
#
#                                   media_path     emoji     youtube  \
# 0  ./downloads\photo_2023-02-10_12-23-06.jpg       ⚠🔅🔅  no youtube
# 1  ./downloads\photo_2023-02-02_08-58-52.jpg         📌  no youtube
# 2  ./downloads\photo_2023-02-01_08-59-37.jpg         📌  no youtube
# 3  ./downloads\photo_2023-01-31_09-19-53.jpg  no emoji  no youtube
# 4  ./downloads\photo_2023-01-30_09-45-25.jpg  no emoji  no youtube
#
#                 website     phone
# 0            no website  no phone
# 1  ('www.chemeds.org',)  no phone
# 2  ('www.chemeds.org',)  no phone
# 3            no website  no phone
# 4            no website  no phone

# %% [markdown]
# 1. create and return engine

# %%
db_connection = TelegramDBManager()
engine = db_connection.get_db_connection()
engine
# Out:
# Engine(postgresql://postgres:***@localhost:2123/week7)

# %% [markdown]
# 2. Create a table

# %%
db_connection.create_table()

# %% [markdown]
# #### Insert Data into database

# %%
# Ensure the 'message_date' column is in datetime format (to prevent NaT issues)
data["message_date"] = pd.to_datetime(data["message_date"], errors="coerce")

# Check if there are any missing values before inserting
missing_values = data.isnull().sum()
print("Missing Values Before Insert:", missing_values)
# Out:
# Missing Values Before Insert: message_id       0
# channel_title    0
# sender           0
# message_date     0
# message          0
# media_path       0
# emoji            0
# youtube          0
# website          0
# phone            0
# dtype: int64

# %%
data.head()
# Out:
#    message_id channel_title         sender              message_date  \
# 0          97        CheMed -1001627056354 2023-02-10 12:23:06+00:00
# 1          96        CheMed -1001627056354 2023-02-02 08:58:52+00:00
# 2          95        CheMed -1001627056354 2023-02-01 08:59:37+00:00
# 3          94        CheMed -1001627056354 2023-01-31 09:19:53+00:00
# 4          93        CheMed -1001627056354 2023-01-30 09:45:25+00:00
#
#                                              message  \
# 0  ️Notice! Dear esteemed customers, Due to four-...
# 1  Mela-One በውስጡ ሆርሞን ያለው ድንገተኛ ወሊድ መቆጣጠርያ ሲሆን ያለ...
# 2  አዚትሮማይሲን በሃኪም መድሃኒት ማዘዣ ከሚታዘዙ አንቲባዮቲኮች አንዱ ሲሆን...
# 3  Che-Med Trivia #3  ምግብና መጠጦች አንዳንድ መድሃኒቶች በደንብ...
# 4  Che-Med Trivia #2  እንደ Ciprofloxacin, Doxycycl...
#
#                                   media_path     emoji     youtube  \
# 0  ./downloads\photo_2023-02-10_12-23-06.jpg       ⚠🔅🔅  no youtube
# 1  ./downloads\photo_2023-02-02_08-58-52.jpg         📌  no youtube
# 2  ./downloads\photo_2023-02-01_08-59-37.jpg         📌  no youtube
# 3  ./downloads\photo_2023-01-31_09-19-53.jpg  no emoji  no youtube
# 4  ./downloads\photo_2023-01-30_09-45-25.jpg  no emoji  no youtube
#
#                 website     phone
# 0            no website  no phone
# 1  ('www.chemeds.org',)  no phone
# 2  ('www.chemeds.org',)  no phone
# 3            no website  no phone
# 4            no website  no phone

# %%
# Insert data into table
db_connection.insert_data(data)

# %% [markdown]
# ###  Verify Inserted Data

# %%
query = "SELECT * FROM telegram_messages LIMIT 5;"
df_pg = pd.read_sql(query, engine)

df_pg
# Out:
#    id channel_title  message_id  \
# 0   1        CheMed          97
# 1   2        CheMed          96
# 2   3        CheMed          95
# 3   4        CheMed          94
# 4   5        CheMed          93
#
#                                              message        message_date  \
# 0  ️Notice! Dear esteemed customers, Due to four-... 2023-02-10 12:23:06
# 1  Mela-One በውስጡ ሆርሞን ያለው ድንገተኛ ወሊድ መቆጣጠርያ ሲሆን ያለ... 2023-02-02 08:58:52
# 2  አዚትሮማይሲን በሃኪም መድሃኒት ማዘዣ ከሚታዘዙ አንቲባዮቲኮች አንዱ ሲሆን... 2023-02-01 08:59:37
# 3  Che-Med Trivia #3  ምግብና መጠጦች አንዳንድ መድሃኒቶች በደንብ... 2023-01-31 09:19:53
# 4  Che-Med Trivia #2  እንደ Ciprofloxacin, Doxycycl... 2023-01-30 09:45:25
#
#                                   media_path     emoji     youtube     phone
# 0  ./downloads\photo_2023-02-10_12-23-06.jpg       ⚠🔅🔅  no youtube  no phone
# 1  ./downloads\photo_2023-02-02_08-58-52.jpg         📌  no youtube  no phone
# 2  ./downloads\photo_2023-02-01_08-59-37.jpg         📌  no youtube  no phone
# 3  ./downloads\photo_2023-01-31_09-19-53.jpg  no emoji  no youtube  no phone
# 4  ./downloads\photo_2023-01-30_09-45-25.jpg  no emoji  no youtube  no phone
